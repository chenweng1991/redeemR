# %% [markdown]
# # variant annotation
# ---
#
# **Author:** Chen Weng
#
# **Date:** Aug 13, 2024
#
# ## Description
# Add more functions to annotate variants
#
#
# ---

# %% [markdown]
# # Load packages

# %%
## Load developing redeemR
devtools::load_all("/lab/solexa_weissman/cweng/Packages/redeemR/")
# Out:
# ℹ Loading redeemR
# Warning message:
# “replacing previous import ‘ape::where’ by ‘dplyr::where’ when loading ‘redeemR’”
# Warning message:
# “replacing previous import ‘ape::keep.tip’ by ‘tidytree::keep.tip’ when loading ‘redeemR’”
# Warning message:
# “replacing previous import ‘ape::drop.tip’ by ‘tidytree::drop.tip’ when loading ‘redeemR’”
# Warning message:
# “replacing previous import ‘Biostrings::translate’ by ‘seqinr::translate’ when loading ‘dndscv’”
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’
#
# Found more than one class "dist" in cache; using the first, from namespace 'spam'
#
# Also defined by ‘BiocGenerics’

# %% [markdown]
# # Load data

# %%
data(haplogroup_markers)
data(mitomap_freq)
data(mito_diseases)
data(mito_homopolymer)

# %% [markdown]
# # Load example redeemR object
# Read in any redeem object to test (recommend to load the variant after filter2)

# %%
Young1_HSC.redeemR_filter2 <- readRDS("/lab/solexa_weissman/cweng/Projects/Collaborator/Teng_Gao/MitoDrift/HSC/01_HSC_filter2_dir/Young1_HSC.redeemR_filter2.obj.rds")$redeemR

# %% [markdown]
# # Run wrap_up functions for variants annotations

# %% [markdown]
# ## run one line

# %%
Young1_HSC.redeemR_filter2@V.fitered <- annotate_all_variants(Young1_HSC.redeemR_filter2@V.fitered)
# Out:
# Warning message:
# “Unknown columns: `ID`, `Locus`, `RSRS50`, `freq_all`, `freq_african`, `freq_asian`, `freq_eurasian`, `haplo_info`, `n_haplos`”
# [1] Loading the environment...
#
# [2] Annotating the mutations...
#
# Warning message in dndscv(mutations_all, refdb = mitorefdb, numcode = 2, max_muts_per_gene_per_sample = 5000, :
# “Mutations observed in contiguous sites within a sample. Please annotate or remove dinucleotide or complex substitutions for best results.”
# [3] Estimating global rates...
#
# [4] Running dNdSloc...
#
# [5] Running dNdScv...
#
# Warning message in theta.ml(Y, mu, sum(w), w, limit = control$maxit, trace = control$trace > :
# “iteration limit reached”
# Warning message in theta.ml(Y, mu, sum(w), w, limit = control$maxit, trace = control$trace > :
# “iteration limit reached”
#     Regression model for substitutions (theta = 3.83e+05).
#
# Warning message:
# “Unknown columns: `Disease`”

# %% [markdown]
# ## run separate

# %%
# Add hypermutable annotation
Young1_HSC.redeemR_filter2@V.fitered <- annotate_variants_hypermutable(Young1_HSC.redeemR_filter2@V.fitered) 

# Add variant population statistics, gene, haplogroup markers¶
Young1_HSC.redeemR_filter2@V.fitered <- annotate_variants_population_stats(Young1_HSC.redeemR_filter2@V.fitered)

# Add black list positions
Young1_HSC.redeemR_filter2@V.fitered <- annotate_variants_blacklist(Young1_HSC.redeemR_filter2@V.fitered)

# Add homopolomer annotation
Young1_HSC.redeemR_filter2@V.fitered <- annotate_variants_homopolymer(Young1_HSC.redeemR_filter2@V.fitered)

# Add variant amino acid change and the gene
Young1_HSC.redeemR_filter2@V.fitered <- annotate_variants_aachange(Young1_HSC.redeemR_filter2@V.fitered)

# Add disease relevance information
Young1_HSC.redeemR_filter2@V.fitered <- annotate_variants_mito_disease(Young1_HSC.redeemR_filter2@V.fitered)

# Add nucleitide change
Young1_HSC.redeemR_filter2@V.fitered <- Annotate_base_change(Young1_HSC.redeemR_filter2@V.fitered)
# Out:
# Warning message:
# “Unknown columns: `ID`, `haplo_info`”
# [1] Loading the environment...
#
# [2] Annotating the mutations...
#
# Warning message in dndscv(mutations_all, refdb = mitorefdb, numcode = 2, max_muts_per_gene_per_sample = 5000, :
# “Mutations observed in contiguous sites within a sample. Please annotate or remove dinucleotide or complex substitutions for best results.”
# Warning message in dndscv(mutations_all, refdb = mitorefdb, numcode = 2, max_muts_per_gene_per_sample = 5000, :
# “Same mutations observed in different sampleIDs. Please verify that these are independent events and remove duplicates otherwise.”
# [3] Estimating global rates...
#
# [4] Running dNdSloc...
#
# [5] Running dNdScv...
#
# Warning message in theta.ml(Y, mu, sum(w), w, limit = control$maxit, trace = control$trace > :
# “iteration limit reached”
# Warning message in theta.ml(Y, mu, sum(w), w, limit = control$maxit, trace = control$trace > :
# “iteration limit reached”
#     Regression model for substitutions (theta = 3.83e+05).

# %%
head(Young1_HSC.redeemR_filter2@V.fitered)
# Out:
#   Variants CellN PositiveMean PositiveMean_cts maxcts CellNPCT   TotalVcount
# 1 6425_T_C 243   0.02250622    1.111111        20     0.03899856  274
# 2 146_T_C  127   0.34191850    7.299213        31     0.02038196  952
# 3 513_G_A   89   0.02760451    1.224719        13     0.01428342  110
# 4 3244_G_A  81   0.15582270    8.481481        51     0.01299952  689
# 5 1348_G_A  79   0.02079220    1.126582         6     0.01267854   91
# 6 5913_G_A  79   0.33335510   19.670886        88     0.01267854 1576
#   TotalCov totalVAF     CV         ⋯ freq_eurasian n_haplos blacklist_region
# 1 351741   0.0007789823 0.04671960 ⋯  0.09         NA
# 2 200949   0.0047375205 0.29552877 ⋯ 16.42         58
# 3 284935   0.0003860530 0.02784759 ⋯  1.18          1       blacklist_region
# 4 443251   0.0015544240 0.27809690 ⋯  0.01         NA
# 5 403824   0.0002253457 0.04595542 ⋯    NA         NA
# 6 404987   0.0038914829 0.28282989 ⋯  1.29          3
#   homopolymer gene   aachange impact     Disease                        changes
# 1 NA          MT-CO1 P174P    Synonymous NA                             T_C
# 2 NA          NA     NA       NA         Absence of Endometriosis       T_C
# 3 NA          NA     NA       NA         NA                             G_A
# 4 NA          NA     NA       NA         NA                             G_A
# 5 NA          NA     NA       NA         NA                             G_A
# 6 NA          MT-CO1 D4N      Missense   Prostate Cancer / hypertension G_A
#   types
# 1 transition
# 2 transition
# 3 transition
# 4 transition
# 5 transition
# 6 transition

# %% [markdown]
# # Breakdown each part

# %% [markdown]
# ## Add variant population statistics, gene, haplogroup markers

# %%
variant_annotation <- Young1_HSC.redeemR_filter2@V.fitered

# %%
data(mitomap_freq)
mitomap_freq <-mitomap_freq[,c("ID","Locus", "RSRS50","Overall.Variant.Frequency.in.Sequence.Set", "Frequency.in.Lineage.L", "Frequency.in.Lineage.M", "Frequency.in.Lineage.N")]
names(mitomap_freq)[4:7] <-c("freq_all","freq_african","freq_asian","freq_eurasian")

# %%
data(haplogroup_markers)
haplogroup_markers_summary <- haplogroup_markers %>%
  group_by(ID) %>%
  summarize(
    haplo_info = paste0(
      paste(haplo, collapse = "_"),  # collapse haplo by “_”
      ";",
      paste(freq, collapse = "_")    # collapse freq by “_”
    ),
    .groups = "drop",
    n_haplos = n()
  )

# %%
variant_annotation <- variant_annotation %>% 
                    select(-one_of(unique(c(names(mitomap_freq),names(haplogroup_markers_summary))))) %>%
                    left_join(mitomap_freq, by = c("Variants" = "ID")) %>%
                    arrange(desc(CellN)) %>% 
                    left_join(haplogroup_markers_summary[, c("ID","n_haplos")], by = c("Variants" = "ID"))
# Out:
# Warning message:
# “Unknown columns: `ID`, `Locus`, `RSRS50`, `freq_all`, `freq_african`, `freq_asian`, `freq_eurasian`, `haplo_info`, `n_haplos`”

# %% [markdown]
# ---

# %% [markdown]
# > Wrap these up annotate_variants_population_stats and update in redeemR Package variant_annotation.R

# %%
#' Annotate variant table with population frequency and haplogroup statistics
#'
#' @description
#' Adds mitochondrial variant information from \code{mitomap_freq} and 
#' haplogroup marker counts from \code{haplogroup_markers} to a variant annotation
#' data frame.  data. It drops any existing columns that would collide, then merges in:
#' \itemize{
#'   \item{\code{Locus}}{Gene name, tRNA, or other feature from \code{mitomap_freq}.}
#'   \item{\code{RSRS50}}{Logical flag indicating whether the variant is an ancestral (RSRS50) variant.}
#'   \item{\code{freq_all, freq_african, freq_asian, freq_eurasian}}{Mitochondrial variant frequencies in the overall, African, Asian, and Eurasian populations, respectively.}
#'   \item{\code{n_haplos}}{Number of population‐level ancestry branches (haplogroups) that consider this variant a marker (posterior >80\%).}
#' }
#'
#' @param variant_annotation A data.frame or tibble containing at least columns \code{Variants} and \code{CellN}.
#'
#' @return The input \code{variant_annotation}, augmented with:
#' \describe{
#'   \item{\code{Locus}}{Feature name (gene/tRNA/etc).}
#'   \item{\code{RSRS50}}{Ancestral variant flag (logical).}
#'   \item{\code{freq_all}}{Overall variant frequency.}
#'   \item{\code{freq_african}}{Variant frequency in African population.}
#'   \item{\code{freq_asian}}{Variant frequency in Asian population.}
#'   \item{\code{freq_eurasian}}{Variant frequency in Eurasian population.}
#'   \item{\code{n_haplos}}{Count of haplogroups (ancestry branches) marking this variant (>80\% posterior).}
#' }
#'
#' @importFrom dplyr select one_of left_join arrange desc group_by summarize
#' @export
annotate_variants_population_stats <- function(variant_annotation){ 
    data(mitomap_freq)
    data(haplogroup_markers)
    mitomap_freq <-mitomap_freq[,c("ID","Locus", "RSRS50","Overall.Variant.Frequency.in.Sequence.Set", "Frequency.in.Lineage.L", "Frequency.in.Lineage.M", "Frequency.in.Lineage.N")]
    names(mitomap_freq)[4:7] <-c("freq_all","freq_african","freq_asian","freq_eurasian")
    haplogroup_markers_summary <- haplogroup_markers %>%
      group_by(ID) %>%
      summarize(
        haplo_info = paste0(
          paste(haplo, collapse = "_"),  # collapse haplo by “_”
          ";",
          paste(freq, collapse = "_")    # collapse freq by “_”
        ),
        .groups = "drop",
        n_haplos = n()
      ) 
    variant_annotation <- variant_annotation %>% 
                        select(-one_of(unique(c(names(mitomap_freq),names(haplogroup_markers_summary))))) %>%
                        left_join(mitomap_freq, by = c("Variants" = "ID")) %>%
                        arrange(desc(CellN)) %>% 
                        left_join(haplogroup_markers_summary[, c("ID","n_haplos")], by = c("Variants" = "ID"))

    return(variant_annotation)
}

# %% [markdown]
# ## Add black list positions

# %% [markdown]
# (1)
# Misalignment due to ACCCCCCCTCCCCC (rCRS 302-315)
#
# (2)
# Misalignment due to GCACACACACACC (rCRS 513-525)
#
# (3)
# Misalignment due to 3107N in rCRS (rCRS 3,105-3,109)
#
# (4)
# Misalignment due to ACCCCC (rCRS 16,182-16,187)

# %%
black_list_regions<-c(302:315, 513:525, 3105:3109, 16182:16187)

# %%
pos<- as.numeric(strsplit(variant_annotation$Variants, "_") %>% sapply(function(x){x[1]}))
variant_annotation$blacklist_region<- ifelse(pos %in% black_list_regions,"blacklist_region","")

# %% [markdown]
# ---

# %% [markdown]
# > wrap these up and update in redeemR Package as annotate_variants_blacklist

# %%
#' Annotate variants with mitochondrial blacklist region flag
#'
#' @description
#' Flags variants whose genomic position falls within known problematic
#' regions of the mitochondrial genome (blacklist regions).
#'
#' @details
#' The blacklist intervals correspond to regions in the revised Cambridge Reference
#' Sequence (rCRS) prone to misalignment:
#' \enumerate{
#'   \item Misalignment due to \code{ACCCCCC T C C C C C C} (rCRS 302–315)
#'   \item Misalignment due to \code{G C A C A C A C A C A C C} (rCRS 513–525)
#'   \item Misalignment due to \code{3107N} ambiguity in rCRS (rCRS 3105–3109)
#'   \item Misalignment due to \code{ACCCCC} homopolymer (rCRS 16182–16187)
#' }
#'
#' @param variant_annotation A data.frame or tibble containing at least a column
#'   named \code{Variants}, where each entry is of the form \code{"<pos>_<ref>_<alt>"}.
#'
#' @return The input \code{variant_annotation} with an added column:
#' \describe{
#'   \item{\code{blacklist_region}}{Character; \code{"blacklist_region"} if the variant
#'     position is in one of the predefined blacklist intervals, otherwise \code{""}.}
#' }
#'
#' @export
annotate_variants_blacklist <- function(variant_annotation){
    black_list_regions<-c(302:315, 513:525, 3105:3109, 16182:16187)
    pos<- as.numeric(strsplit(variant_annotation$Variants, "_") %>% sapply(function(x){x[1]}))
    variant_annotation$blacklist_region<- ifelse(pos %in% black_list_regions,"blacklist_region","")
    return(variant_annotation)
}

# %% [markdown]
# ## Add homopolomer annotation

# %%
# for each pos, find the first interval that contains it
pos<- as.numeric(strsplit(variant_annotation$Variants, "_") %>% sapply(function(x){x[1]}))
assigned <- sapply(pos, function(pos) {
  idx <- which(mito_homopolymer$V2 <= pos & pos <= mito_homopolymer$V3)
  if (length(idx)) mito_homopolymer$V4[idx[1]] else NA
})

# assemble result
pos_homopolymer <- data.frame(
  position = pos,
  V4        = assigned,
  stringsAsFactors = FALSE
)

variant_annotation <- variant_annotation %>% mutate(homopolymer = pos_homopolymer$V4)

# %% [markdown]
# ---

# %% [markdown]
# > wrap up above and update in redeemR Package as annotate_variants_homopolymer

# %%
#' Annotate variants with mitochondrial homopolymer context
#'
#' @description
#' Flags each variant by the homopolymer region in which its position falls,
#' based on predefined mitochondrial homopolymer intervals.
#'
#' @details
#' The function loads the \code{mito_homopolymer} data frame, which must contain
#' columns \code{V2} (start), \code{V3} (end), and \code{V4} (region label).
#' For each variant position, it finds the first homopolymer interval that
#' contains that position and assigns its label; otherwise, \code{NA}.
#'
#' @param variant_annotation A data.frame or tibble containing at least a column
#'   named \code{Variants}, where each entry is of the form \code{"<pos>_<ref>_<alt>"}.
#'
#' @return The input \code{variant_annotation} with an added column:
#' \describe{
#'   \item{\code{homopolymer}}{Character; the label of the homopolymer region
#'     (from \code{mito_homopolymer\$V4}) containing the variant position, or
#'     \code{NA} if none.}
#' }
#'
#' @importFrom dplyr mutate
#' @export
annotate_variants_homopolymer <- function(variant_annotation){
    data(mito_homopolymer)   
    pos<- as.numeric(strsplit(variant_annotation$Variants, "_") %>% sapply(function(x){x[1]}))
    # for each pos, find the first interval that contains it
    assigned <- sapply(pos, function(pos) {
      idx <- which(mito_homopolymer$V2 <= pos & pos <= mito_homopolymer$V3)
      if (length(idx)) mito_homopolymer$V4[idx[1]] else NA
    })

    # assemble result
    pos_homopolymer <- data.frame(
      position = pos,
      V4        = assigned,
      stringsAsFactors = FALSE
    )
    variant_annotation <- variant_annotation %>% mutate(homopolymer = pos_homopolymer$V4)
    return(variant_annotation)
}

# %% [markdown]
# ## Add variant amino acid change and the gene
# (optional) <br/>
# Dependency: library(https://github.com/im3sanger/dndscv)

# %%
#' Parse mitochondrial variants into a tidy table
#'
#' @description
#' Internal helper to split variant strings of the form `"<pos>_<ref>_<mut>"`
#' into a data frame with columns for sample ID, chromosome, position, reference,
#' and alternate allele.
#'
#' @param variants Character vector of variant strings, e.g. `"123_A_G"`.
#' @param ID       Character scalar; sample identifier to assign to all rows.
#'
#' @return A data.frame with columns:
#'
#' @keywords internal
#' @noRd
make_mutation_table<-function(variants,ID=""){
    mito_mutations<-strsplit(variants,"_") %>% do.call(rbind,.) %>% as.data.frame()
    mito_mutations<-data.frame(sampleID=ID,chr="MT",mito_mutations)
    names(mito_mutations)[3:5]<-c("pos","ref","mut")
    mito_mutations$pos<-as.integer(mito_mutations$pos)
    return(mito_mutations)
}

# %%
require(dndscv)

# %%
mitorefdb <- system.file("data", "GRCH38_MT_bioMRT_output_refcds.rda",package = "redeemR")

# %%
mutations_all<-make_mutation_table(variant_annotation$Variants,"")

# %%
mito_dndsout_all = dndscv(mutations_all,refdb=mitorefdb,numcode = 2,max_muts_per_gene_per_sample = 5000,max_coding_muts_per_sample = 5000)
# Out:
# [1] Loading the environment...
#
# [2] Annotating the mutations...
#
# Warning message in dndscv(mutations_all, refdb = mitorefdb, numcode = 2, max_muts_per_gene_per_sample = 5000, :
# “Mutations observed in contiguous sites within a sample. Please annotate or remove dinucleotide or complex substitutions for best results.”
# [3] Estimating global rates...
#
# [4] Running dNdSloc...
#
# [5] Running dNdScv...
#
# Warning message in theta.ml(Y, mu, sum(w), w, limit = control$maxit, trace = control$trace > :
# “iteration limit reached”
# Warning message in theta.ml(Y, mu, sum(w), w, limit = control$maxit, trace = control$trace > :
# “iteration limit reached”
#     Regression model for substitutions (theta = 3.83e+05).

# %%
mito_aa_annotation<- mito_dndsout_all$annotmuts %>% mutate(Variants= paste(pos, ref, mut, sep="_")) %>%
select(Variants, gene, aachange, impact)

# %%
variant_annotation <- variant_annotation %>% select(-any_of(c("aachange", "impact"))) %>% left_join(mito_aa_annotation,by = "Variants")

# %% [markdown]
# ---

# %% [markdown]
# > wrap up above and update in redeemR Package as annotate_variants_aachange

# %%
#' Annotate variants with amino-acid change and predicted impact via dndscv
#'
#' @description
#' Runs dndscv on the mitochondrial variants to obtain gene-level
#' annotation of amino-acid changes and their predicted impact.
#'
#' @details
#' This internal function:
#' 1. Loads the precomputed mitochondrial CDS reference database from the
#'    redeemR package (`GRCH38_MT_bioMRT_output_refcds.rda`).
#' 2. Converts `Variants` ("<pos>_<ref>_<alt>") into the 5-column table
#'    required by dndscv using `make_mutation_table`.
#' 3. Runs `dndscv()` with permissive mutation limits to annotate all coding
#'    changes.
#' 4. Extracts and merges back the `gene`, `aachange`, and `impact` fields
#'    for each variant.
#'
#' @param variant_annotation A data.frame or tibble containing at least a column
#'   named `Variants` of the form "<pos>_<ref>_<alt>".
#'
#' @return The input `variant_annotation`, augmented with columns:
#' \describe{
#'   \item{gene}{Gene symbol where the variant falls.}
#'   \item{aachange}{Amino-acid change notation (e.g. p.W88C).}
#'   \item{impact}{Predicted functional impact category from dndscv.}
#' }
#'
#' @importFrom dndscv dndscv
#' @importFrom dplyr mutate select left_join any_of
#' @export
annotate_variants_aachange <- function(variant_annotation){
    require(dndscv)
    mitorefdb <- system.file("data", "GRCH38_MT_bioMRT_output_refcds.rda",package = "redeemR")
    mutations_all<- make_mutation_table(variant_annotation$Variants,"")
    mito_dndsout_all <- dndscv(mutations_all,refdb=mitorefdb,numcode = 2,max_muts_per_gene_per_sample = 5000,max_coding_muts_per_sample = 5000)
    mito_aa_annotation<- mito_dndsout_all$annotmuts %>% 
                         mutate(Variants= paste(pos, ref, mut, sep="_")) %>%
                         select(Variants, gene, aachange, impact)
    variant_annotation <- variant_annotation %>% select(-any_of(c("aachange", "impact"))) %>% left_join(mito_aa_annotation,by = "Variants")
}

# %% [markdown]
# ## Add disease relevance information

# %%
data(mito_diseases)

# %%
variant_annotation <- variant_annotation %>% 
                    select(-one_of(unique(c("Disease")))) %>%
                    left_join(mito_diseases[,c("ID","Disease")], by = c("Variants" = "ID"))
# Out:
# Warning message:
# “Unknown columns: `Disease`”

# %% [markdown]
# ---

# %% [markdown]
# > wrap up for function annotate_variants_mito_disease

# %%
#' Annotate variants with mitochondrial disease associations
#'
#' @description
#' Adds disease annotations from the \code{mito_diseases} dataset for each variant.
#'
#' @param variant_annotation A data.frame or tibble containing at least a column
#'   named \code{Variants}.
#'
#' @return The input \code{variant_annotation} with an added column:
#' \describe{
#'   \item{Disease}{Disease association from \code{mito_diseases}, or \code{NA} if none.}
#' }
#'
#' @importFrom dplyr select one_of left_join
#' @export
#' Annotate variants with mitochondrial disease associations
#'
#' @description
#' Adds disease annotations from the mito_diseases dataset for each variant.
#'
#' @param variant_annotation A data.frame or tibble containing at least a column named \code{Variants}.
#'
#' @return The input \code{variant_annotation} with an added column:
#' \describe{\item{Disease}{Disease association(s) from \code{mito_diseases}, NA if none.}}
#' @importFrom dplyr select one_of left_join
#' @export
annotate_variants_mito_disease <- function(variant_annotation){
    data(mito_diseases)
    variant_annotation <- variant_annotation %>% 
                    select(-one_of(unique(c("Disease")))) %>%
                    left_join(mito_diseases[,c("ID","Disease")], by = c("Variants" = "ID"))
    return(variant_annotation)
}

# %% [markdown]
# # Update the variant summary statistics from mtx

# %%
#' Create variant summary table from count matrix
#'
#' @description
#' Summarizes a variant-by-cell count matrix to produce per-variant metrics.
#'
#' @details
#' Calculates for each variant (column of \code{mtx}):
#' \itemize{
#'   \item{\code{cellN}}{Number of cells with count > 0.}
#'   \item{\code{max_count}}{Maximum count observed across cells.}
#'   \item{\code{mean_count}}{Mean of non-zero counts.}
#'   \item{\code{ct1_cellN}}{Number of cells with count == 1.}
#'   \item{\code{ct2_cellN}}{Number of cells with count == 2.}
#'   \item{\code{ct3plus_cellN}}{Number of cells with count > 2.}
#'   \item{\code{pct_ct2plus}}{Fraction of cells with count >= 2.}
#'   \item{\code{cellNPCT}}{Fraction of cells with count > 0 relative to total cells.}
#' }
#'
#' @param mtx Numeric matrix with variants as columns and cells as rows.
#'
#' @return A data.frame with one row per variant, including the metrics above and a 
#'         column \code{Variants} with variant identifiers (column names of \code{mtx}).
#'
#' @importFrom tibble rownames_to_column
#' @importFrom dplyr mutate
#' @export
make_V.fitered_from_mtx<- function(mtx){
    mtx_summarystat<-data.frame(CellN=apply(mtx, 2, function(x){sum(x>0)}),
    max_count=apply(mtx, 2, max),
    mean_count=apply(mtx, 2, function(x){mean(x[x>0])}),
    ct1_cellN=apply(mtx, 2, function(x){length(x[x==1])}),
    ct2_cellN=apply(mtx, 2, function(x){length(x[x==2])}),
    ct3plus_cellN=apply(mtx, 2, function(x){length(x[x>2])})                  
    ) %>% 
    tibble::rownames_to_column("Variants") %>%
    mutate(Variants = convert_variant(Variants), pct_ct2plus=(ct2_cellN+ct3plus_cellN)/CellN) %>% mutate(cellNPCT=CellN/nrow(mtx))
    return(mtx_summarystat)
}

# %%
variant_summary_stat_from_mtx <- make_V.fitered_from_mtx(Young1_HSC.redeemR_filter2@Cts.Mtx)

# %%
annotate_all_variants(variant_summary_stat_from_mtx)
# Out:
# Warning message:
# “Unknown columns: `ID`, `Locus`, `RSRS50`, `freq_all`, `freq_african`, `freq_asian`, `freq_eurasian`, `haplo_info`, `n_haplos`”
# [1] Loading the environment...
#
# [2] Annotating the mutations...
#
# Warning message in dndscv(mutations_all, refdb = mitorefdb, numcode = 2, max_muts_per_gene_per_sample = 5000, :
# “Mutations observed in contiguous sites within a sample. Please annotate or remove dinucleotide or complex substitutions for best results.”
# [3] Estimating global rates...
#
# [4] Running dNdSloc...
#
# [5] Running dNdScv...
#
# Warning message in theta.ml(Y, mu, sum(w), w, limit = control$maxit, trace = control$trace > :
# “iteration limit reached”
# Warning message in theta.ml(Y, mu, sum(w), w, limit = control$maxit, trace = control$trace > :
# “iteration limit reached”
#     Regression model for substitutions (theta = 3.83e+05).
#
# Warning message:
# “Unknown columns: `Disease`”
#      Variants  CellN max_count mean_count ct1_cellN ct2_cellN ct3plus_cellN
# 1    1000_T_C   3     4         2.000000  2         0         1
# 2    10005_A_G  2     3         2.000000  1         0         1
# 3    10007_T_C  2     3         2.500000  0         1         1
# 4    10009_G_A  2    10         5.500000  1         0         1
# 5    10010_T_C  3    12         4.666667  2         0         1
# 6    10020_T_C  6    13         4.833333  1         2         3
# 7    10031_T_C  3     2         1.333333  2         1         0
# 8    1004_G_A   4     3         2.000000  2         0         2
# 9    10045_T_C  2    32        16.500000  1         0         1
# 10   1005_T_C   6     7         2.000000  5         0         1
# 11   10054_G_A  7    11         2.428571  6         0         1
# 12   1006_T_C   9    30         4.555556  7         0         2
# 13   10063_A_G  4     4         2.750000  1         1         2
# 14   10066_T_C  4     5         2.000000  3         0         1
# 15   10068_G_A 10     4         1.900000  6         1         3
# 16   10071_T_C  4     2         1.250000  3         1         0
# 17   10075_T_C  2    12         6.500000  1         0         1
# 18   10078_T_C  2     5         3.000000  1         0         1
# 19   1008_A_G   2     2         1.500000  1         1         0
# 20   10081_T_C  3    33        11.666667  2         0         1
# 21   10083_A_G  2     5         3.000000  1         0         1
# 22   10084_T_C  4     8         3.250000  2         0         2
# 23   10088_C_T  6     7         2.000000  5         0         1
# 24   10093_T_C  9     5         1.444444  8         0         1
# 25   10098_G_A  7    13         3.000000  5         0         2
# 26   10101_T_C 10     4         1.500000  8         0         2
# 27   10102_T_C  2     3         2.000000  1         0         1
# 28   10114_T_C  7    28        12.285714  2         0         5
# 29   10115_T_C  4    18         6.250000  1         1         2
# 30   10126_G_A  5     7         2.200000  4         0         1
# ⋮    ⋮         ⋮     ⋮         ⋮          ⋮         ⋮         ⋮
# 3753 9914_A_G  13    36        3.692308   12        0         1
# 3754 9915_G_A  12    11        2.000000    9        2         1
# 3755 9918_G_A  51    12        1.235294   49        1         1
# 3756 9921_G_A   7    11        2.428571    6        0         1
# 3757 9925_G_A   8     5        1.875000    6        0         2
# 3758 9927_T_C   4    19        6.750000    1        1         2
# 3759 9928_A_G   6     4        1.500000    5        0         1
# 3760 9932_G_A  15    32        3.533333   12        0         3
# 3761 9934_A_G   2     3        2.000000    1        0         1
# 3762 9938_T_C   4     5        2.250000    2        1         1
# 3763 9939_G_A  10    10        2.800000    7        0         3
# 3764 9940_T_C   2    12        7.000000    0        1         1
# 3765 9942_G_A  15    36        6.800000    8        0         7
# 3766 9947_G_A  10    32        4.500000    6        2         2
# 3767 9948_G_A  10    17        5.000000    6        0         4
# 3768 9948_G_C   2    10        5.500000    1        0         1
# 3769 9949_T_C   2     7        4.000000    1        0         1
# 3770 9950_T_C  13     6        1.384615   12        0         1
# 3771 9964_A_G   6    13        5.166667    3        0         3
# 3772 9965_T_C   3     4        2.000000    2        0         1
# 3773 9966_G_A   6     8        2.833333    4        0         2
# 3774 9967_T_C   4     3        1.500000    3        0         1
# 3775 9973_T_C   7    18        4.000000    5        0         2
# 3776 9977_T_C   8     4        1.750000    6        0         2
# 3777 9978_T_C   4    21        7.500000    1        1         2
# 3778 9985_G_A  14     3        1.142857   13        0         1
# 3779 9986_G_A  10     7        1.600000    9        0         1
# 3780 9987_T_C   5    11        3.200000    3        1         1
# 3781 9993_T_C   4    10        3.750000    2        0         2
# 3782 9998_T_C   2     3        2.000000    1        0         1
#      pct_ct2plus cellNPCT     hyper_label ⋯ freq_eurasian n_haplos
# 1    0.3333333   0.0005104645             ⋯   NA          NA
# 2    0.5000000   0.0003403097             ⋯ 0.02          NA
# 3    1.0000000   0.0003403097             ⋯ 0.10          NA
# 4    0.5000000   0.0003403097             ⋯   NA          NA
# 5    0.3333333   0.0005104645             ⋯   NA          NA
# 6    0.8333333   0.0010209290             ⋯ 0.01          NA
# 7    0.3333333   0.0005104645             ⋯ 0.18           2
# 8    0.5000000   0.0006806194             ⋯   NA          NA
# 9    0.5000000   0.0003403097             ⋯ 0.04          NA
# 10   0.1666667   0.0010209290             ⋯ 0.62           8
# 11   0.1428571   0.0011910839             ⋯   NA          NA
# 12   0.2222222   0.0015313936             ⋯ 0.00          NA
# 13   0.7500000   0.0006806194             ⋯   NA          NA
# 14   0.2500000   0.0006806194             ⋯   NA          NA
# 15   0.4000000   0.0017015484             ⋯   NA          NA
# 16   0.2500000   0.0006806194             ⋯ 0.00          NA
# 17   0.5000000   0.0003403097             ⋯   NA          NA
# 18   0.5000000   0.0003403097             ⋯   NA          NA
# 19   0.5000000   0.0003403097             ⋯ 0.07          NA
# 20   0.3333333   0.0005104645             ⋯ 0.00          NA
# 21   0.5000000   0.0003403097             ⋯ 0.00          NA
# 22   0.5000000   0.0006806194             ⋯ 0.83           1
# 23   0.1666667   0.0010209290             ⋯ 0.04          NA
# 24   0.1111111   0.0015313936             ⋯   NA          NA
# 25   0.2857143   0.0011910839             ⋯   NA          NA
# 26   0.2000000   0.0017015484             ⋯ 0.25           1
# 27   0.5000000   0.0003403097             ⋯   NA          NA
# 28   0.7142857   0.0011910839             ⋯ 0.01          NA
# 29   0.7500000   0.0006806194             ⋯ 0.03           5
# 30   0.2000000   0.0008507742             ⋯   NA          NA
# ⋮    ⋮           ⋮            ⋮           ⋱ ⋮             ⋮
# 3753 0.07692308  0.0022120129             ⋯ 0.00          NA
# 3754 0.25000000  0.0020418581             ⋯   NA          NA
# 3755 0.03921569  0.0086778969             ⋯   NA          NA
# 3756 0.14285714  0.0011910839             ⋯ 0.13           1
# 3757 0.25000000  0.0013612387             ⋯   NA          NA
# 3758 0.75000000  0.0006806194             ⋯   NA          NA
# 3759 0.16666667  0.0010209290             ⋯   NA          NA
# 3760 0.20000000  0.0025523226             ⋯ 0.40           2
# 3761 0.50000000  0.0003403097             ⋯   NA          NA
# 3762 0.50000000  0.0006806194             ⋯ 0.13          NA
# 3763 0.30000000  0.0017015484             ⋯   NA          NA
# 3764 1.00000000  0.0003403097             ⋯   NA          NA
# 3765 0.46666667  0.0025523226             ⋯   NA          NA
# 3766 0.40000000  0.0017015484             ⋯ 1.13           2
# 3767 0.40000000  0.0017015484             ⋯ 0.21          NA
# 3768 0.50000000  0.0003403097             ⋯   NA          NA
# 3769 0.50000000  0.0003403097             ⋯   NA          NA
# 3770 0.07692308  0.0022120129             ⋯ 4.73          17
# 3771 0.50000000  0.0010209290             ⋯   NA          NA
# 3772 0.33333333  0.0005104645             ⋯ 0.01          NA
# 3773 0.33333333  0.0010209290             ⋯ 0.57           5
# 3774 0.25000000  0.0006806194             ⋯ 0.01          NA
# 3775 0.28571429  0.0011910839             ⋯   NA          NA
# 3776 0.25000000  0.0013612387             ⋯ 0.03          NA
# 3777 0.75000000  0.0006806194             ⋯   NA          NA
# 3778 0.07142857  0.0023821678             ⋯ 0.00          NA
# 3779 0.10000000  0.0017015484             ⋯ 0.21           1
# 3780 0.40000000  0.0008507742             ⋯ 0.00          NA
# 3781 0.50000000  0.0006806194             ⋯   NA          NA
# 3782 0.50000000  0.0003403097             ⋯   NA          NA
#      blacklist_region homopolymer gene   aachange impact
# 1                     NA          NA     NA       NA
# 2                     NA          NA     NA       NA
# 3                     NA          NA     NA       NA
# 4                     NA          NA     NA       NA
# 5                     NA          NA     NA       NA
# 6                     NA          NA     NA       NA
# 7                     NA          NA     NA       NA
# 8                     NA          NA     NA       NA
# 9                     NA          NA     NA       NA
# 10                    NA          NA     NA       NA
# 11                    NA          NA     NA       NA
# 12                    NA          NA     NA       NA
# 13                    NA          MT-ND3 N2S      Missense
# 14                    NA          MT-ND3 F3S      Missense
# 15                    NA          MT-ND3 A4T      Missense
# 16                    NA          MT-ND3 L5L      Synonymous
# 17                    T_run_4     MT-ND3 I6T      Missense
# 18                    T_run_4     MT-ND3 L7S      Missense
# 19                    NA          NA     NA       NA
# 20                    NA          MT-ND3 M8T      Missense
# 21                    NA          MT-ND3 I9V      Missense
# 22                    NA          MT-ND3 I9T      Missense
# 23                    NA          MT-ND3 N10N     Synonymous
# 24                    NA          MT-ND3 L12P     Missense
# 25                    NA          MT-ND3 A14T     Missense
# 26                    NA          MT-ND3 L15L     Synonymous
# 27                    NA          MT-ND3 L15S     Missense
# 28                    NA          MT-ND3 I19T     Missense
# 29                    NA          MT-ND3 I19I     Synonymous
# 30                    NA          MT-ND3 W23*     Nonsense
# ⋮    ⋮                ⋮           ⋮      ⋮        ⋮
# 3753                  NA          MT-CO3 E236E    Synonymous
# 3754                  NA          MT-CO3 A237T    Missense
# 3755                  NA          MT-CO3 A238T    Missense
# 3756                  NA          MT-CO3 A239T    Missense
# 3757                  NA          MT-CO3 W240*    Nonsense
# 3758                  NA          MT-CO3 Y241H    Missense
# 3759                  NA          MT-CO3 Y241C    Missense
# 3760                  NA          MT-CO3 W242W    Synonymous
# 3761                  T_run_4     MT-CO3 H243R    Missense
# 3762                  T_run_4     MT-CO3 F244F    Synonymous
# 3763                  NA          MT-CO3 V245M    Missense
# 3764                  NA          MT-CO3 V245A    Missense
# 3765                  NA          MT-CO3 D246N    Missense
# 3766                  NA          MT-CO3 V247V    Synonymous
# 3767                  NA          MT-CO3 V248I    Missense
# 3768                  NA          MT-CO3 V248L    Missense
# 3769                  NA          MT-CO3 V248A    Missense
# 3770                  NA          MT-CO3 V248V    Synonymous
# 3771                  NA          MT-CO3 Y253C    Missense
# 3772                  NA          MT-CO3 Y253Y    Synonymous
# 3773                  NA          MT-CO3 V254I    Missense
# 3774                  NA          MT-CO3 V254A    Missense
# 3775                  NA          MT-CO3 I256T    Missense
# 3776                  NA          MT-CO3 Y257Y    Synonymous
# 3777                  NA          MT-CO3 W258R    Missense
# 3778                  NA          MT-CO3 G260E    Missense
# 3779                  NA          MT-CO3 G260G    Synonymous
# 3780                  NA          MT-CO3 S261P    Missense
# 3781                  NA          NA     NA       NA
# 3782                  T_run_4     NA     NA       NA
#      Disease                       changes types
# 1    NA                            T_C     transition
# 2    NA                            A_G     transition
# 3    NA                            T_C     transition
# 4    NA                            G_A     transition
# 5    NA                            T_C     transition
# 6    NA                            T_C     transition
# 7    NA                            T_C     transition
# 8    NA                            G_A     transition
# 9    NA                            T_C     transition
# 10   NA                            T_C     transition
# 11   NA                            G_A     transition
# 12   NA                            T_C     transition
# 13   NA                            A_G     transition
# 14   NA                            T_C     transition
# 15   NA                            G_A     transition
# 16   NA                            T_C     transition
# 17   NA                            T_C     transition
# 18   NA                            T_C     transition
# 19   NA                            A_G     transition
# 20   NA                            T_C     transition
# 21   NA                            A_G     transition
# 22   NA                            T_C     transition
# 23   NA                            C_T     transition
# 24   NA                            T_C     transition
# 25   NA                            G_A     transition
# 26   NA                            T_C     transition
# 27   NA                            T_C     transition
# 28   NA                            T_C     transition
# 29   NA                            T_C     transition
# 30   NA                            G_A     transition
# ⋮    ⋮                             ⋮       ⋮
# 3753 NA                            A_G     transition
# 3754 NA                            G_A     transition
# 3755 NA                            G_A     transition
# 3756 Possible LHON helper mutation G_A     transition
# 3757 NA                            G_A     transition
# 3758 NA                            T_C     transition
# 3759 NA                            A_G     transition
# 3760 NA                            G_A     transition
# 3761 NA                            A_G     transition
# 3762 NA                            T_C     transition
# 3763 NA                            G_A     transition
# 3764 NA                            T_C     transition
# 3765 NA                            G_A     transition
# 3766 NA                            G_A     transition
# 3767 NA                            G_A     transition
# 3768 NA                            G_C     transversion
# 3769 NA                            T_C     transition
# 3770 NA                            T_C     transition
# 3771 NA                            A_G     transition
# 3772 NA                            T_C     transition
# 3773 LHON possible helper variant  G_A     transition
# 3774 NA                            T_C     transition
# 3775 NA                            T_C     transition
# 3776 NA                            T_C     transition
# 3777 NA                            T_C     transition
# 3778 NA                            G_A     transition
# 3779 NA                            G_A     transition
# 3780 NA                            T_C     transition
# 3781 NA                            T_C     transition
# 3782 NA                            T_C     transition
